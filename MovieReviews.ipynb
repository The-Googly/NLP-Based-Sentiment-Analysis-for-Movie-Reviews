# %%
# !pip install tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

# %%
imdb = tf.keras.datasets.imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# ...
# 17464789/17464789 [==============================] - 1s 0us/step

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

#preprocessing the data
train_data = pad_sequences(train_data, maxlen = 250, padding = 'post', truncating = 'post')
test_data = pad_sequences(test_data, maxlen = 250, padding = 'post', truncating = 'post')

# %%
print(test_data.size)
# Out:
# 6250000

# %%
vocab_size = 10000
embedding_dim = 16
model = Sequential()
model.add(Embedding(input_dim = vocab_size, output_dim = embedding_dim, input_length = 250))
model.add(LSTM(units = 25))
#model.add(Dropout(0.2))
model.add(Dense(units = 1, activation = 'sigmoid'))
model.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

model.fit(train_data, train_labels, epochs = 8, batch_size = 64, shuffle = True, validation_split = 0.1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-bfb26da26d85> in <cell line: 25>()
#      23     return embedding_matrix
#      24 glove_path = 'path/to/glove.6B.100d.txt'
# ---> 25 glove_embeddings = load_glove_embeddings(glove_path, embedding_dim)
#      26
#      27 # Create the embedding matrix
#
# <ipython-input-5-bfb26da26d85> in load_glove_embeddings(embedding_path, dimension)
#       4 def load_glove_embeddings(embedding_path, dimension):
#       5     embeddings_index = {}
# ----> 6     with open(embedding_path, 'r', encoding='utf-8') as f:
#       7         for line in f:
#       8             values = line.split()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/glove.6B.100d.txt'

# %%
loss, accuracy = model.evaluate(test_data, test_labels)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
# Out:
# 782/782 [==============================] - 4s 5ms/step - loss: 0.5949 - accuracy: 0.6816
# Test Loss: 0.5949, Test Accuracy: 0.6816
